# %%
import os
import time
import pandas as pd

os.chdir('D:\\PhD\\References\\ICIAL-2017\\Extracting Contract Elements\\Dataset\\dictionaries')
df=pd.read_csv('word_embeddings.csv')

# %%
print(df.shape)
print(df)
# Out:
# (514368, 1)
# ...
